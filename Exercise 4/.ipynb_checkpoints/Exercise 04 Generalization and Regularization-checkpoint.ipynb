# %% [markdown]
# # In Sample Error and Out Sample Error

# %%
# %matplotlib inline
import math
import numpy as np
from matplotlib import pyplot as plt
from scipy.optimize import fmin, minimize

# %% [markdown]
# 1) Try to fit the following data with a straight line. Plot data points along with actual function and your line.

# %%
np.random.seed(7777)
ndata = 12
z = [0.6, -0.5, 0.4, -0.3, 0.2, -0.1]
a,b,c,d,e,f = z
noise = 0.15
xs = np.linspace(-1, 1, ndata)
tx = xs
ys = (a*tx**5 + b*tx**4 + c*tx**3 + d*tx**2 + e*tx + f) + np.random.randn(ndata)*noise
actualxs = np.linspace(-1,1,100)
tx = actualxs
actualys = (a*tx**5 + b*tx**4 + c*tx**3 + d*tx**2 + e*tx + f)

ntest = 300
testxs = np.linspace(-1,1,ntest)
tx = testxs
testys = (a*tx**5 + b*tx**4 + c*tx**3 + d*tx**2 + e*tx + f) + np.random.randn(ntest)*noise

plt.plot(xs, ys,'or')
plt.plot(actualxs, actualys,'b')
plt.plot(testxs, testys, '.k', alpha=0.3)

# %%
#put your code here
# def guess(w, x):
#     m, c = w
#     return m*x + c

# def cost(w):
#     return (sum((yy - guess(w, xx))**2 for xx, yy in zip(xs, ys)))/len(xs)

# w = minimize(cost, [0,0]).x

# newx = np.linspace(-1, 1, 100)
# newy = [guess(w, xx) for xx in newx]
# plt.plot(xs, ys, 'or')
# plt.plot(newx, newy)
# plt.plot(actualxs, actualys)

# %% [markdown]
# 2) What is your in-sample error? $E_{in}$

# %% [markdown]
# 3) What is your out-sample error? $E_{out}$

# %% [markdown]
# 4) Between $E_{in}$ and $E_{out}$
# - Which one do we really want to optimize?
# - Which one do we actually optimize when we train our model?

# %% [markdown]
# 5) Now Try fit it with polynomial degree 2 ($ax^2 + bx + c)$. Same deal, plot, find $E_{in}$ and $E_{out}$. (Think about a generic function that does this for any number of degree)

# %%
def guess2(w, x, d):
    return sum(ww*x**i for i, ww in enumerate(w))
#    return sum(ww*(x**(len(w)-dd)) for ww, dd in zip(w,xrange(1, d+1)))
#     s = 0
#     for i in xrange(len(w)):
#         #print d, i
#         s += w[i]*(x**(d-i-1))
#     return s


def cost(w):
    return (sum((yy - guess2(w, xx, len(w)))**2 for xx, yy in zip(xs, ys)))/len(xs)

for i in xrange(2, 12):
    w = minimize(cost, [0]*i).x

    newx = np.linspace(-1, 1, 100)
    newy = [guess2(w, xx, len(w)) for xx in newx]
    plt.figure()
    plt.plot(xs, ys, 'or')
    plt.plot(newx, newy)
    plt.plot(actualxs, actualys)

# %% [markdown]
# 6) Try it with degree 3, 4, 5 ... 11. Can you explain what happen at degree 11?
#
# <span style="color:red;"> DO NOT COPY PASTE codes. Write a function and use for loop </span>

# %%
def guess2(w, x, d):
    return sum(ww*x**i for i, ww in enumerate(w))

def cost(w):
    return (sum((yy - guess2(w, xx, len(w)))**2 for xx, yy in zip(xs, ys)))/len(xs)

def outCost(w):
    return (sum((yy - guess2(w, xx, len(w)))**2 for xx, yy in zip(testxs, testys)))/len(testxs)

minObj = []
for i in xrange(2, 12):
    minObj.append(minimize(cost, [0]*i))

inE = []
for i in xrange(2, 12):
    inE.append(minObj[i - 2].fun)

outE = []
for i in xrange(2, 12):
    outE.append( outCost(minObj[i - 2].x) )
    
    
    
newx = np.linspace(2, 12, 10)
plt.figure()
#plt.plot(xs, ys, 'or')
plt.plot(newx, inE)
plt.plot(newx, outE)
#plt.plot(actualxs, actualys)

# %% [markdown]
# 7) Now plot polynomial degree vs $E_{in}$ and degree vs $E_{out}$

# %%
for o in minObj:
    print o.x, " "
# Out:
# [-0.29327995  0.7385295 ]
# [ 0.07039661  0.73852731 -0.92317671]
# [ 0.07037946 -0.09031407 -0.92313491  1.17988302]
# [ 0.02949323 -0.09032589 -0.56521541  1.17989987 -0.36176845]
# [ 0.02947574 -0.10454025 -0.56513741  1.23921694 -0.36182808 -0.04717764]
# [ 0.03658142 -0.10440675 -0.70345987  1.23863927  0.01862274 -0.04670529
#  -0.25251539]
# [  3.62811213e-02  -7.67833573e-01  -6.98023577e-01   6.98275215e+00
#    4.23287260e-03  -1.20243709e+01  -2.43176253e-01   6.91899404e+00]
# [ -5.47311789e-03  -7.64884455e-01   8.41047559e-01   6.95739564e+00
#   -8.51083778e+00  -1.19718532e+01   1.43272182e+01   6.88880291e+00
#   -7.55734125e+00]
# [ -3.79192645e-03  -1.15420579e+00   7.85522903e-01   1.31536186e+01
#   -8.22113972e+00  -3.76116758e+01   1.38483017e+01   4.48320386e+01
#   -7.31421127e+00  -1.81118783e+01]
# [ -1.10719606e-01  -1.14279831e+00   7.86816760e+00   1.29579445e+01
#   -8.01357703e+01  -3.67695057e+01   2.58800045e+02   4.35572981e+01
#   -3.34214635e+02  -1.74949558e+01   1.46888857e+02]

# %% [markdown]
# 8) Explain why you see the graph you see in above.
#
# - What's wrong with model that is too simple
# - What's wrong with model that is too complex

# %% [markdown]
# # Regularization.

# %% [markdown]
# 1) Print $w$ from those degree 11 polynomial model. What went wrong with overly complex model?

# %%
def cost2(w):
    ld = [10.0**(-10), 0.01, 10.0**5, 0.01]
    return ( (sum((yy - guess2(w, xx, len(w)))**2 for xx, yy in zip(xs, ys)))/len(xs) ) + ld[3]*sum(ww**2 for ww in w)

i = 50
w = minimize(cost2, [0]*i).x

newx = np.linspace(-1, 1, 100)
newy = [guess2(w, xx, len(w)) for xx in newx]
plt.figure()
plt.plot(xs, ys, 'or')
plt.plot(newx, newy)
plt.plot(actualxs, actualys)

# %% [markdown]
# 2) How should we penalize the model to prevent overly complex model?
#
# In particular, what is does the penalized cost function looks like?

# %% [markdown]
# 3) What happen if our penalty is too small?

# %% [markdown]
# 4) What happend if our penalty is too big?

# %% [markdown]
# 5)Try Regularize with $\lambda=1\times10^{-8}$, $\lambda=0.01$ and $\lambda=100$

# %%
#currying



# l = np.linspace(-10, 3, 200)
# minObj = []
# for ll in l:
#     minObj.append(minimize(cost_function(ll), [0]*11))


# inE = []
# for i in xrange(200):
#     inE.append( cost(minObj[i].x) )

# outE = []
# for i in xrange(200):
#     outE.append( outCost(minObj[i].x) )
    
    
    
# newx = []
# for i in xrange(200):
#     newx.append(math.pow(10,l[i]))
def guess(w, x):
    return sum(ww*x**i for i, ww in enumerate(w))

def closeness(w, xs, ys):
    return sum( (yy-guess(w, xx))**2 for xx,yy in zip(xs, ys))/len(xs)

def find_eout(w):
    return closeness(w, testxs, testys)

def find_ein(w):
    return closeness(w, xs, ys)

def cost_function(l):
    def cost(w):
        return closeness(w, xs, ys) + l*sum(ww**2 for ww in w[1:])
    return cost

lambdas = np.linspace(-10, 3, 200)
ein = []
eout = []
ls = []
for l in lambdas:
    l = math.pow(10, l)
    cost = cost_function(l)
    w = minimize(cost, [0]*11).x
    ls.append(np.log(1.0)/l)
    ein.append(find_ein(w))
    eout.append(find_eout(w))

# %%
plt.figure()

plt.plot(newx, inE, 'r')
plt.plot(newx, outE, 'g')

# %% [markdown]
# # Model Selection

# %% [markdown]
# 1) Why don't  we just use every single data to train?

# %% [markdown]
# 2) What is validation data set for?

# %% [markdown]
# 3) Why is it that we can't use validation set to report the expected out of sample performance?

# %% [markdown]
# 4) What is test data set for?

# %% [markdown]
# 5) What's wrong if we use too much data set for validation and test sample?

# %% [markdown]
# # Logistic regression revisited
#
# (if we have time if not it's your hw)
#
# Try build a classifier to classify this data

# %%
class1 = np.zeros((1000,3))
class1[:, 0] = 1.
class1[:, 1] = np.random.randn(1000)+3
class1[:, 2] = np.random.randn(1000)+2

class2 = np.zeros((1000,3))
class2[:, 0] = -1
class2[:, 1] = np.random.random(1000)*10-2
class2[:, 2] = np.random.random(1000)*10-2

data = np.concatenate([class1, class2])

class1idx = data[:,0] == 1

class2idx = data[:,0] == -1

plt.plot(data[class1idx, 1], data[class1idx, 2], '.b', alpha=0.3)
plt.plot(data[class2idx, 1], data[class2idx, 2], '.r', alpha=0.3)
print data
# Out:
# [[ 1.          2.83183225  2.21788396]
#  [ 1.          3.24505985  1.33380711]
#  [ 1.          4.20791006  2.17029943]
#  ...,
#  [-1.          5.79041673  3.63972547]
#  [-1.          6.88819689  4.26226006]
#  [-1.         -0.78355493  4.35778885]]
